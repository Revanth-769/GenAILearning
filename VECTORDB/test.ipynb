# %%
import requests
import json

url = "https://api.euron.one/api/v1/euri/embeddings"
api_token = "euri-15626beca1faa283e4147b25cfae0696f11e76f12cc85a0aab76aaa9e91b8839"

headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_token}"
}

data = {
    "input": "My name is Revanth",
    "model": "text-embedding-3-small"
}

response = requests.post(url, headers=headers, data=json.dumps(data))

if response.status_code == 200:
    embedding_data = response.json()
    print(embedding_data)
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# {'object': 'list', 'data': [{'object': 'embedding', 'embedding': [0.0086263865, -0.017725628, -0.013124888, -0.0056870254, -0.09232151, -0.0068691596, -0.04035871, 0.022262467, -0.017866205, -0.027834475, -0.0062046084, -0.014735146, -0.016396524, 0.014198394, 0.047489855, -0.004792437, 0.02890798, -0.013239906, -0.012997089, 0.032384094, 0.039949756, -0.012549795, 0.02213467, 0.013814999, -0.010319714, 0.013112108, 0.013124888, 0.018454077, 0.019144189, -0.08910099, 0.03724043, -0.027936714, 0.0056071514, 0.011348491, -0.046314113, 0.015092982, 0.008958662, -0.05086373, -0.0032971967, 0.06681296, 0.012575354, -0.021252861, 0.037163753, 0.045138367, 0.004709368, 0.0048148017, -0.107964024, 0.0053483597, 0.041815612, -0.015910892, -0.025738582, -0.038492855, 0.012275029, 0.033713195, -0.0014744732, -0.018454077, 0.021585137, 0.031847343, 0.0028499025, -0.0010687135, 0.02663317, 0.007687069, 0.007431472, 0.013265465, -0.04342587, 0.0059585967, -0.00029633235, 0.0065816133, 0.019949319,
# ...

# %%
len(embedding_data['data'][0]['embedding'])
# Out:
# 1536

# %%
a = embedding_data['data'][0]['embedding']

# %%
import requests
import json

url = "https://api.euron.one/api/v1/euri/embeddings"
api_token = "euri-15626beca1faa283e4147b25cfae0696f11e76f12cc85a0aab76aaa9e91b8839"

headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_token}"
}

data = {
    "input": "Shravya is revanth's Girl friend",
    "model": "text-embedding-3-small"
}

response = requests.post(url, headers=headers, data=json.dumps(data))

if response.status_code == 200:
    embedding_data_1 = response.json()
    print(embedding_data)
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# {'object': 'list', 'data': [{'object': 'embedding', 'embedding': [0.0086263865, -0.017725628, -0.013124888, -0.0056870254, -0.09232151, -0.0068691596, -0.04035871, 0.022262467, -0.017866205, -0.027834475, -0.0062046084, -0.014735146, -0.016396524, 0.014198394, 0.047489855, -0.004792437, 0.02890798, -0.013239906, -0.012997089, 0.032384094, 0.039949756, -0.012549795, 0.02213467, 0.013814999, -0.010319714, 0.013112108, 0.013124888, 0.018454077, 0.019144189, -0.08910099, 0.03724043, -0.027936714, 0.0056071514, 0.011348491, -0.046314113, 0.015092982, 0.008958662, -0.05086373, -0.0032971967, 0.06681296, 0.012575354, -0.021252861, 0.037163753, 0.045138367, 0.004709368, 0.0048148017, -0.107964024, 0.0053483597, 0.041815612, -0.015910892, -0.025738582, -0.038492855, 0.012275029, 0.033713195, -0.0014744732, -0.018454077, 0.021585137, 0.031847343, 0.0028499025, -0.0010687135, 0.02663317, 0.007687069, 0.007431472, 0.013265465, -0.04342587, 0.0059585967, -0.00029633235, 0.0065816133, 0.019949319,
# ...

# %%
b = embedding_data_1['data'][0]['embedding']

# %%
import requests
import json

url = "https://api.euron.one/api/v1/euri/embeddings"
api_token = "euri-15626beca1faa283e4147b25cfae0696f11e76f12cc85a0aab76aaa9e91b8839"

headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_token}"
}

data = {
    "input": "Rakesh is genai batch student",
    "model": "text-embedding-3-small"
}

response = requests.post(url, headers=headers, data=json.dumps(data))

if response.status_code == 200:
    embedding_data_2 = response.json()
    print(embedding_data)
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# {'object': 'list', 'data': [{'object': 'embedding', 'embedding': [0.0086263865, -0.017725628, -0.013124888, -0.0056870254, -0.09232151, -0.0068691596, -0.04035871, 0.022262467, -0.017866205, -0.027834475, -0.0062046084, -0.014735146, -0.016396524, 0.014198394, 0.047489855, -0.004792437, 0.02890798, -0.013239906, -0.012997089, 0.032384094, 0.039949756, -0.012549795, 0.02213467, 0.013814999, -0.010319714, 0.013112108, 0.013124888, 0.018454077, 0.019144189, -0.08910099, 0.03724043, -0.027936714, 0.0056071514, 0.011348491, -0.046314113, 0.015092982, 0.008958662, -0.05086373, -0.0032971967, 0.06681296, 0.012575354, -0.021252861, 0.037163753, 0.045138367, 0.004709368, 0.0048148017, -0.107964024, 0.0053483597, 0.041815612, -0.015910892, -0.025738582, -0.038492855, 0.012275029, 0.033713195, -0.0014744732, -0.018454077, 0.021585137, 0.031847343, 0.0028499025, -0.0010687135, 0.02663317, 0.007687069, 0.007431472, 0.013265465, -0.04342587, 0.0059585967, -0.00029633235, 0.0065816133, 0.019949319,
# ...

# %%
c = embedding_data_2['data'][0]['embedding']

# %%
import requests
import json

url = "https://api.euron.one/api/v1/euri/embeddings"
api_token = "euri-15626beca1faa283e4147b25cfae0696f11e76f12cc85a0aab76aaa9e91b8839"

headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {api_token}"
}

data = {
    "input": "What Revanth does",
    "model": "text-embedding-3-small"
}

response = requests.post(url, headers=headers, data=json.dumps(data))

if response.status_code == 200:
    embedding_data_3 = response.json()
    inp= embedding_data_3['data'][0]['embedding']
    print(embedding_data)
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# {'object': 'list', 'data': [{'object': 'embedding', 'embedding': [0.0086263865, -0.017725628, -0.013124888, -0.0056870254, -0.09232151, -0.0068691596, -0.04035871, 0.022262467, -0.017866205, -0.027834475, -0.0062046084, -0.014735146, -0.016396524, 0.014198394, 0.047489855, -0.004792437, 0.02890798, -0.013239906, -0.012997089, 0.032384094, 0.039949756, -0.012549795, 0.02213467, 0.013814999, -0.010319714, 0.013112108, 0.013124888, 0.018454077, 0.019144189, -0.08910099, 0.03724043, -0.027936714, 0.0056071514, 0.011348491, -0.046314113, 0.015092982, 0.008958662, -0.05086373, -0.0032971967, 0.06681296, 0.012575354, -0.021252861, 0.037163753, 0.045138367, 0.004709368, 0.0048148017, -0.107964024, 0.0053483597, 0.041815612, -0.015910892, -0.025738582, -0.038492855, 0.012275029, 0.033713195, -0.0014744732, -0.018454077, 0.021585137, 0.031847343, 0.0028499025, -0.0010687135, 0.02663317, 0.007687069, 0.007431472, 0.013265465, -0.04342587, 0.0059585967, -0.00029633235, 0.0065816133, 0.019949319,
# ...

# %%
import numpy as np

# %%
pip install numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 677.3 kB/s  0:00:07 eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
type(a)
# Out:
# list

# %%
a = np.array(a)
b = np.array(b)
c= np.array(c)
inp = np.array(inp)

# %%
dist_inp_a = np.linalg.norm(inp-a)
dist_inp_b = np.linalg.norm(inp-b)
dist_inp_c = np.linalg.norm(inp-c)

# %%
dist_inp_a, dist_inp_b, dist_inp_c
# Out:
# (np.float64(0.7291635539007231),
#  np.float64(0.9528806488053708),
#  np.float64(1.1202358232754976))
